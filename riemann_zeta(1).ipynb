# %% [markdown]
# # **The Riemann zeta function**
#
#
#
# <br>
#
# <h2><center><b> MATH 3076, 3976, 4076 </b></center></h2>
#
# <br>
#
# <h2><center><b> Due: 11:59PM, 8 May 2021 (SATURDAY). </b></center></h2>
#
# <br>
#
# ## **INSTRUCTIONS (READ CAREFULLY):**
#
# ### MARKING GUIDELINES
#
# * **1) Each sub TASK will have detailed instructions. Read these and the mathematical background carefully.**
#
#
# * **2) TEST your results EXTENSIVELY. You can check against the Examples but also check with lots of different inputs.**
#
#
# * **3) I will make sure your code runs without errors and gives the correct results in a reasonable amount of time. I do not care about the fine details of how you get it to work. I only care about the output, not the specific implementation.**
#
#
# * **4) Getting part of a function working is better than getting nothing. For example, I will check if functions give correct answers for correct inputs. And I will check to see if functions give proper error messages with invalid input. But getting correct answers with correct input is more important than handling errors.**
#
#
# * **5) I will expect correct results to machine roundoff. Roughly smaller than `1e-14`.**
#
#
# * **6) All section MATH3076/3976/4076 must complete all the TASKS in this notebook.**
#
#
# <br>
#
#
# ## **MARKING DIRECTIVES:**
#
# -------------------
#
# **Your assignments should have 3 types of cells:**
#
# **1. "Markdown" type cells (like this one) that contain everything that isn't your code.**
#
# **2. "Code" type cells with a heading like the following:**
#
# `### TEST FUNCTION: test_function_name`
#
# `# DO NOT REMOVE ANYTHING IN THIS CELL`
#
# **These are the ONLY cells that will be marked. This is where you put your code.**
#
# **Each TASK has a unique name (e.g. `test_function_name`) that is required for that TASK.**
#
# **3. "Code" type cells with the heading:**
#
# `### SKIP`
#
# `# This code will not be marked.`
#
# **Put any testing in these types of cells.**
#
# **Do not create any other types of cells. This is equivalent to submitting in a clean handwritten assignment.**
#
# **If you create any new cells for marking, you MUST include the same `###SKIP` comment at the top.**
#
# -------------------
#
# **You will lose marks if you don't obey the above rules.**
#
#
# **You will get 0 marks for a question that isn't in the correct `### TEST FUNCTION` cell.**
#
#
# **You will get 0 marks for a question if you change the required function interface.**
#
#
# **You will get 0 marks for a question if you return more data than the instructions ask for.**
#
#
# **The "Mark" button is needed to log the submission time for your assignment. Make sure to press it when you want to submit. It won't do anything else until after the due date.**
#
#
# **Do not submit your assignment after the deadline. Otherwise, it will be late.**
#
#
# **No late submissions will be counted without special considerations.**
#
#
# **Do not "Reset to Scaffold" after the deadline. Your work may be lost.**
#
# <br>
#
# ### Otherwise, have fun and good luck!
#
# <br>
#
# <br>

# %% [markdown]
# # **Background info**
#
# You have all probably at least heard of the famous function,
#
# $$
# \zeta(s) \ = \ \sum_{n=1}^{\infty} \frac{1}{n^{s}}.
# $$
#
# This is one of the most (maybe *the* most) significant functions in all of mathematics. Probably the main reason for this importance is the many relations to the prime numbers. Chiefly, Euler proved the alternative representation
#
# $$
# \zeta(s) \ = \ \prod_{p \,  \text{prime}} \frac{1}{1-p^{-s}}
# $$
#
# Of course, you've also probably heard about the famous "Riemann hypothesis". We'll get back to this later.
#
# ### **Special cases**
#
# Euler first proved the special case,
#
# $$
# \zeta(2) \ = \ \sum_{n=1}^{\infty} \frac{1}{n^{2}} \ = \  \frac{\pi^{2}}{6}.
# $$
#
# This is the "Basel problem". It was at the forefront of mathematics in the early 1700s. Euler worked it out in 1734 as one of his first notable achievements.
#
# Another useful special case is
#
# $$
# \zeta(4) \ = \ \frac{\pi^{4}}{90}.
# $$
#
# In general, for integer $k$,
#
# $$
# \zeta(2k) \ = \ \frac{(-1)^{k+1} (2\pi)^{2k} B_{2k}}{2 (2k)!},
# $$
#
# where $B_{2k}$ are the even Bernoulli numbers. No simple formula is known for odd-integer arguments. But
#
# $$
# \zeta(3) \ = \ 1.2020569031595942854\dots,
# $$
#
# which has the special name, *Apéry's constant.*
#
# ### **Convergence**
#
# There's one major caveat to the original sum. It only converges for
#
# $$
# \text{Re(s)} > 1.
# $$
#
# There is another problem. Even for $\text{Re}(s) > 1$ the convergence can be *very slow*.
#
#
# ### **Alternating series acceleration**
#
# We can use a clever trick to improve things a bit. Notice for any *convergent* sum
#
# $$
# \sum_{n=1}^{\infty} \ = \ \sum_{n \, \text{odd}}  \ + \ \sum_{n \, \text{even}}.
# $$
#
# We need to use the qualifier *convergent*. It's not true in general that we can rearrange the terms in an infinite sum. But let's ignore the fine print for now as long as things are working for us.
#
# Going a step further, for any convergent sum,
#
# $$
# \sum_{n=1}^{\infty}a_{n} \ = \ \sum_{n=1}^{\infty} (-1)^{n+1} a_{n}  \ + \ 2\sum_{n=1}^{\infty} a_{2n}.
# $$
#
# Here's the crux:
#
# $$
# a_{n} \ = \ \frac{1}{n^{s}} \qquad \implies \qquad a_{2n} \ = \ \frac{a_{n}}{2^{s}}.
# $$
#
# This means that for the Riemann zeta function
#
# $$
# \zeta(s) \ = \ \frac{1}{1-2^{1-s}} \sum_{n=1}^{\infty} \frac{(-1)^{n+1}}{n^{s}}.
# $$
#
# We've written the original series in terms of an *alternating series*! This will give the same answer where the original version converged. But it also happens to converge for
#
# $$
# \text{Re}(s) > 0, \qquad \text{provided} \qquad 2^{1-s} \ \ne \ 1.
# $$
#
#
# ### **The Riemann hypothesis**
#
# Aside from popular appeal, the Riemann hypothesis (RH) is notable because it's equivalent to a vast number of major pure mathematical results. Many theorems are "proven", assuming the hypothesis is true. If it's false, a lot of work will fall alongside. What is the RH?
#
# First, when dealing with complex-valued inputs, it's common to define
#
# $$
# s = \sigma + i t,
# $$
#
# where $\sigma = \text{Re}(s)$, and $t = \text{Im}(s)$. The alternating series converges for $\sigma > 0$. The RH is the following
#
# $$
# \zeta(s) \ = \ 0 \qquad \iff \qquad s = \frac{1}{2} + i \, t,
# $$
#
# We can also extend the zeta function to negative inputs. In that case, there exists another simple family of zeros. But *at this point*, the only zeros are expected to have a real part of *exactly* 1/2. It is known that all the non-trivial zeros lie in what's called the "critical strip" where $0 < \text{Re}(s) < 1$. This fact is also equivalent to the "Prime Number Theorem", which is obviously very impressive. So it's a bit of a giveaway that the RH is closely linked to lots of important math.
#
# There's still a big problem with the function as we've currently defined it. While technically the series converges for (e.g.) $\sigma = 1/2$, it does so ***ridiculously, tediously, slowly***. For example,
#
# $$
# \sum_{n = 1}^{\infty} \frac{(-1)^{n+1}}{\sqrt{n}} \ = \ 0.60489864342163037025...
# $$
#
# But getting only **3 digits** (0.604) takes over **one million** terms in the sum!
#
# If we want to find any zeros of the zeta function, we are going to need some better tricks.
#
# <br>
#
# ## **Euler summation**
#
# Euler was a smart guy. He figured out a way to seriously *accelerate* alternating sums. It works by using *finite differences*.
#
#
# Start with a sequence:
#
# $$
# a \ = \ (a_{0}, \, a_{1}, \, a_{2},\, \ldots)
# $$
#
# Compute the first *forward finite difference*
#
# $$
# \Delta a \ = \ (a_{1}-a_{0}, \, a_{2}-a_{1}, \, a_{3}-a_{2},\, \ldots).
# $$
#
# We can repeat the operation
#
# $$
# \Delta^{2} a \ = \ (\Delta a_{1}-\Delta a_{0}, \, \Delta a_{2}-\Delta a_{1}, \, \Delta a_{3}-\Delta a_{2},\, \ldots).
# $$
#
# In terms of the original sequence,
#
# $$
# \Delta^{2} a \ = \ ( a_{2} - 2 a_{1} + a_{0}, \, a_{3} - 2 a_{2} + a_{1}, \, a_{4} - 2 a_{3} + a_{2},\, \ldots).
# $$
#
# And
#
# $$
# \Delta^{3} a \ = \ ( a_{3} - 3 a_{2} + 3 a_{1} - a_{0}, \, a_{4} - 3 a_{3} + 3 a_{2} - a_{1}, \, a_{5} - 3 a_{4} + 3 a_{3} - a_{2},\, \ldots).
# $$
#
# We can keep going. In each case, we can take the 0-th term in the $n$th finite-difference sequence,
#
# $$
# b_{n} \ = \ (\Delta^{n} a)_{\,0}.
# $$
#
# There's an explicit formula for the result
#
# $$
# b_{n} \ = \ \sum_{k=0}^{n} \binom{n}{k} (-1)^{k} a_{n-k}.
# $$
#
# But even though there's a "closed-form" expression, it's best to compute $b_{n}$ directly, differencing the sequence multiple times.
#
#
# The main result is that for any convergent alternating series,
#
# $$
# \sum_{n=0}^{\infty} (-1)^{n} a_{n} \ = \ \sum_{n=0}^{\infty} \frac{(-1)^{n}}{2^{n+1}} (\Delta^{n} a)_{\,0}.
# $$
#
# Proving it isn't very hard. It mainly requires the good-old "reversing-the-sums trick":
#
# $$
# \sum_{n=0}^{\infty}\sum_{k=0}^{n} \ = \ \sum_{n=0}^{\infty}\sum_{k=0}^{\infty} \text{If}\,( k \le n)  \ = \ \sum_{k=0}^{\infty} \sum_{n=k}^{\infty}.
# $$
#
# After this, the only thing that's need is
#
# $$
# \sum_{k=n}^{\infty} \binom{n}{k} \frac{1}{2^{n+1}} \ = \ 1,
# $$
#
# which you can prove with some effort by differentiating a geometric series $k+1$ times.
#
# Overall, Euler summation is a *weird* result.
#
# * The condition for convergence is only that $\lim_{n\to \infty} a_{n} = 0$.
#
#
# * The finite differences will usually decrease even faster.
#
#
# * The $2^{n+1}$ in the denominator means that the series actually converges *geometrically*, even if the original series is rubbish.
#
#
# * In the case of $s=1/2$, we can get **5 correct digits** using only **ten** terms in the Euler sum; it would take roughly *ten billion* terms in the original alternating version of the series.
#
#
# * Finally, the Euler sum can converge in cases where it's absurd for the original series to converge. For example when $s < 0$.
#
# Putting everything together,
#
# $$
# \zeta(s) \ = \ \frac{1}{1-2^{1-s}}\sum_{n = 0}^{\infty} \frac{1}{2^{n+1}} \sum_{k=0}^{n}\binom{n}{k} \frac{(-1)^{k}}{(k+1)^{s}}
# $$
#
# It turns out this is a **globally converging series**. It works for any $s$ in the complex plane, provided $2^{1-s} \ne 1$.
#
# **But be careful!** This series is appealing in closed-form. But it's best to think of it as an Euler summation accelerated alternating series. The binomial coefficients become very large, e.g.,
#
# $$
# \binom{50}{25} \ = \ 126410606437752.
# $$
#
# So ***do not*** try to compute the inner sum directly. Compute it by *differencing* the original series.
#
#
# ### **Extra special cases**
#
# We can now try the series with $s < 0$. For example, $s=-1$ and
#
# $$
# a_{n} = n \qquad (\Delta a)_{n} \ = \ 1, \qquad (\Delta^{2} a)_{n} \ = \ 0 \quad \text{for} \quad n > 1.
# $$
#
# After a finite number of terms, the differencing vanishes. We can put everything together and find the famous results
#
# $$
# \zeta(0) \ = \ -\frac{1}{2}, \qquad \zeta(-1) \ = \ -\frac{1}{12}.
# $$
#
# More generally, for integer $k$,
#
# $$
# \zeta(-k) \ = \ \frac{(-1)^{k}B_{k+1}}{k+1},
# $$
#
# where we again find the Bernoulli numbers.
#
# Negative even integers are also roots for the zeta function on the full complex plane,
#
# $$
# \zeta(-2k) \ = \ 0.
# $$
#
# The full statement of the Riemann hypothesis excludes these "trivial zeros".
#
# Finally, the zeta function has a proper "pole" at $s=1$. But even then, it's possible to get something useful. The "principle value" at $s=1$ is
#
# $$
# \lim_{\varepsilon \to 0} \frac{\zeta(1+\varepsilon)+\zeta(1-\varepsilon)}{2} \ = \ \gamma \ = \ 0.57721566490153286061\ldots,
# $$
#
# where $\gamma$ is the Euler-Mascheroni constant. Getting the principal value correct would be one of the most difficult tests for any numerical implementation. It's quite hard to get more than 7-9 decimal digits.
#
#
#
# ### **Reflection**
#
# There is one more caveat to everything so far. The formula for the Euler summation is technically valid for the whole complex plane. But it starts behaving badly for large negative values of $\text{Re}(s)$.
#
# There is one more magical formula to the rescue,
#
# $$
# \zeta(s) \ = \ 2^{s} \pi^{1-s} \sin\left( \frac{\pi s}{2}\right) \,\Gamma(1-s) \,\zeta(1-s),
# $$
#
#
# The reflection formula works everywhere in the complex plane. You can use it to compute $\zeta(s)$ for (e.g.) $\text{Re}(s) < -5$.
#
# The famous $\Gamma$ function is
#
# $$
# \Gamma(s) \ = \ \int_{0}^{\infty} x^{s-1} e^{-x} \,\text{d}x
# $$
#
# Also, there is another special function called *digamma* that is defined such that
#
# $$
# \psi(s) \ = \ \frac{\Gamma'(s)}{\Gamma(s)} \ = \ \frac{d}{ds} \log \Gamma(s).
# $$
#
#
# <br>

# %% [markdown]
# # **General implementation guidelines**
#
# Below, you will receive specific instructions for defining a collection of Python functions relating to the Riemann zeta function, its derivatives, and its roots. Before going into details, it is worth mentioning a few general principles regarding how the functions should operate and what sort of tests they should pass.
#
# ### **Good enough**
#
# First, as a general rule, it's reasonable to implement a version of your function that works well in a limited set of cases rather than not-so-well in a large collection of cases. If you can do nothing else, the best thing would be to program a function that can:
#
# * Compute the Riemann zeta function reasonably accurately in a reasonable amount of time for one single input at a time.
#
#
# * Reasonably accuracy means (roughly) more than 12 correct digits for modest sizes inputs.
#
#
# * For the Riemann zeta function, the hardest inputs will be for $s \approx 1$. Larger (e.g., $s>10$) inputs should converge more easily. Extremely large inputs might also require special care. But you are doing well if you get good answers for the known exact answers given for (e.g.) $s=2,4,6,\ldots$ and $s=0,-1,-2,\ldots$.
#
#
# * For all the cases ", a reasonable amount of time" means instantaneously for moderate inputs.
#
#
# * Your function should work correctly for positive, negative, and complex-valued inputs. A small amount of care is needed in formulating accurate arithmetic with inputs with large imaginary components.
#
#
# ### **Convergence**
#
# The Riemann zeta function results from an infinite series. Obviously, you will somehow need to truncate the sum at a finite number of terms. There are several considerations in this regard.
#
# * The series error will *very roughly* decrease by a factor of two with each new term.
#
#
# * Here is a fact:
#
#         In [0]: 2**-53
#         Out[0]: 1.1102230246251565e-16
#
#
# * You can use simple estimates to decide how many terms you want in your series.
#
#
#
# * If you do this, you'll probably want to include a bit of a safety buffer on top of your estimate.
#
#
#
# * But don't overdo it (e.g. including 1000s of needless terms). If you compute too many terms, it will slow things down, and you might lose marks on speed for a large number of inputs.
#
#
#
# * The reason why it's difficult to know how many terms to include is that the numerator depends on $s$. So a more nuanced approach would have a convergence check and stopping condition. If you don't have enough convergence, you could keep going.
#
#
#
# * But a dynamic stopping condition will be a bit annoying to implement. So don't do it if you don't think you can get it working correctly. Again, this goes to having enough convergence for reasonable inputs and perhaps somewhat less accuracy for more difficult inputs. Again, the hardest cases will be for $s \approx 1$.
#
#
#
# * If you do hardcode a specific cutoff, then experiment with the exact number to make sure it strikes a good balance between accuracy with speed in most cases.
#
#
# * As mentioned already, $\text{Re}(s) < 0$ poses challanges for convergence. You can use the reflection formula directly for $\zeta(-s)$ in terms of $\zeta(s+1)$ and $\Gamma(s)$. Getting this working is not as important as moderate negative $s$ values.
#
#
# * You can also compute $\zeta'(-s)$ by including the `digamma` function, $\psi(s)$. However, we mostly care about $\zeta'(s)$ to help find roots with $\Re(s) = 1/2$. It's therefore not as important that you implement large negative input values for the derivative.
#
#
# ### **Use `numpy`**
#
# If you ever in this assignment, find yourself saying, "Wow! This stuff is crazy hard and complicated to program." That's when you should ask, "I wonder if `numpy` does what I need?" I've rigged the assignment so that the answer to your question is usually "Yes."
#
# The overall point of this assignment is to have you implement something novel, given the powerful tools at your disposal. If you are doing things right, you might spend a fair bit of your time googling to see if `numpy` does this or that. When I wrote the solutions, I had to figure out how to fix a couple of minor type conversion issues involving `int`, `float` and `complex` for `np.array` objects. A quick trip to google produced the info in about 5 minutes.
#
# And because I'm a nice guy, I'll give you a valuable freebie.
#
#         In [1]: np.diff([5,6,7,8])
#         Out[1]: array([1, 1, 1])
#
# Notice the lengths of the input and output are different!
#
#
#
# ### **Better**
#
#
# If you can get things working in the "Good enough" scenario, you should also try to improve the generality of your code. In particular:
#
# * You should ***vectorise*** your input.
#
#
# * Vectorise means all your functions work on *whole arrays* of inputs. For example,
#
#         In [2]: np.sin(np.array([1,2,3]))
#         Out[2]: array([0.84147098, 0.90929743, 0.14112001])
#
#
# * If you can vectorise for `np.array` objects, it's easy to do the same with `list` and `tuple` objects, i.e.,
#
#
#         In [3]: np.sin([1,2,3])
#         Out[3]: array([0.84147098, 0.90929743, 0.14112001])
#
#         In [4]: np.sin((1,2,3))
#         Out[4]: array([0.84147098, 0.90929743, 0.14112001])
#
#
# * ***Broadcasting*** is the best way to vectorise your calculations internally. I've talked about it several times over the semester. But so that you know what I mean:
#
#         In [5]: np.array([1,2])[:,None] + np.array([3,3])[None,:]
#         Out[5]: array([[4, 4],
#                        [5, 5]])
#
# * You are going to what to check if your input is an array or not. You can do this in several ways. For example, a `try` block, or `isinstance`, or something else. Google these if you haven't picked up the lingo quite yet.
#
#
# * For speed, you will do *much better* if you rely on `numpy` as much as possible. You probably can do everything in a Pythion loop. And some things will probably require an old-fashioned Python loop. But the more you can offload to optimised `numpy` functions, the better.
#
#
# * You will probably run into `dtype` conversion issues when vectorising with `complex128` versus `float64` etc. Getting this right is part of the difficulty. Make sure you test all kinds of different input and make sure you don't have errors.
#
#
# * If you can only vectorise your code with one type of input (e.g. `float64`), then that's better than not vectorising at all. But if you do only get real arrays to work, make sure that `complex` single inputs still work.
#
#
# ### **Moral of the story.**
#
# * If you are completely successful, you should write all the requested functions and have them give machine-precision results very quickly for large numbers of vectorised inputs over a large dynamic range.
#
#
# * If you are successful enough to have done a satisfactory job, you will get good results for moderate-sized complex-valued numbers, one input at a time.
#
#
# * Your mark will improve the more difficult tests your functions can pass. But the more challenging tests are likely going to be worth progressively fewer points. The easy things are where most of the marks are.
#
#
# * With all tests, we will mark things as a matter of degree. The more correct digits you can get, the better. The faster you can get, the better. But there isn't a rule that says (e.g.) 10 digits is not good enough, but 12 digits are ok. It might be that 9 digits are excellent for some inputs, and 14 digits are not very difficult with other inputs.
#
#
# <br>

# %% [markdown]
# <br>
#
# # **Begin TASKS**
#
# <br>

# %% [markdown]
# # **`import`**
#
#
# You are *only* allowed to use the following `import` statements:
#
#
# * `import numpy as np`
#
#
# * `from scipy.special import gamma, digamma`
#
#
# It will be impossible to do any of the TASKS without `numpy`. You should only try to use `gamma` and `digamma` if you have everything else working nicely first.
#
# If you look hard, you might find a `zeta` function implementation in the Python universe. ***Be warned!*** The best thing you'll find out there *has bugs*, and I know how they manifest. Some of my tests will catch cases that don't work.
#
# <br>

# %%
import numpy as np
from scipy.special import gamma, digamma

# %% [markdown]
# <br>

# %% [markdown]
# # **TASK 0**
#
# Write a function called `zeta(s)` that computes the Riemann zeta function defined above using Euler summation. ***Ideally,***
#
#
# * The function should give the correct output for any valid complex-valued input, `s`.
#
#
# * The result should be converged to machine precision, roughly 15-16 decimal digits.
#
#
# * The function should be vectorised over `np.array`, `list` and `tuple` objects.
#
#
# * The function should run at a similar speed (within a factor of 10-100) to other built-in `numpy` functions like `np.sin`, `np.cos`, `np.exp`, `np.tanh`, etc.
#
#
# * If you want, you can include any additional ***optional*** arguments along with `s`. These could be used (e.g.) to control the number of terms in the series. But ***do not*** add any more required arguments. This will break the testing.

# %%
### TEST FUNCTION: test_zeta
# DO NOT REMOVE ANYTHING IN THIS CELL

def zeta(s):
    """ Computes the Riemann zeta function in the complex plane.
    
    Parameters
    ----------
    s : array_like
        Real or complex valued argument

    Returns
    -------
    scalar or ndarray
        Values of the Riemann zeta function
    
    """
    
    ### YOU CODE BELOW THIS LINE ###
    
    
    return

# %%
### SKIP
# This code will not be marked.

# %% [markdown]
# <br>

# %% [markdown]
# # **Derivative**
#
# We can differentiate the Riemann zeta function by noting that
#
# $$
# \frac{d}{ds} \sum_{n=1}^{\infty} \frac{(-1)^{n+1}}{n^{s}} \ = \ \sum_{n=1}^{\infty} \frac{(-1)^{n} \log(n)}{n^{s}}.
# $$
#
# * Given this, it's straightforward to write an expression for $\zeta'(s)$ using the alternating series version of $\zeta(s)$.
#
#
# * You'll also need to differentiate $1/(1-2^{1-s})$ and use the product rule.
#
#
# * Given an alternating series representation for $\zeta'(s)$, you can use Euler summation to accelerate the computation of the series.
#
# <br>

# %% [markdown]
# # **TASK 1**
#
# Write a function called `zeta_prime(s)` that computes the *derivative* of the Riemann zeta function defined above using Euler summation. ***Ideally,***
#
#
#
# * The function should give the correct output for any valid complex-valued input, `s`.
#
#
# * The result should be converged to machine precision, roughly 15-16 decimal digits.
#
#
# * The function should be vectorised over `np.array`, `list` and `tuple` objects.
#
#
# * The function should run at a similar speed (within a factor of 10-100) to other built-in `numpy` functions like `np.sin`, `np.cos`, `np.exp`, `np.tanh`, etc.
#
#
# * `zeta_prime(s)` can use `zeta(s)` if you find that useful.
#
#
# * If you want, you can include any additional ***optional*** arguments along with `s`. These could be used (e.g.) to control the number of terms in the series. But ***do not*** add any more required arguments. This will break the testing.

# %%
### TEST FUNCTION: test_zeta_prime
# DO NOT REMOVE ANYTHING IN THIS CELL

def zeta_prime(s):
    """ Computes the 1st derivative of the Riemann zeta function in the complex plane.
    
    Parameters
    ----------
    s : array_like
        Real or complex valued argument

    Returns
    -------
    scalar or ndarray
        Values of the derivative of the Riemann zeta function
        
    """
    
    ### YOU CODE BELOW THIS LINE ###
    
    
    return

# %%
### SKIP
# This code will not be marked.

# %% [markdown]
# <br>

# %% [markdown]
# # **Roots**
#
# For simplicity, we will assume the Riemann hypothesis is correct. Tell me if you discover otherwise. I'll give you a very good mark for the course.
#
# The non-trivial roots of the Riemann zeta function are symmetric across the real axis. That means that
#
# $$
# s \ = \ \frac{1}{2} \pm i\, t
# $$
#
# are both roots if one of them is.
#
# We can use Newton's method to find roots of the zeta function given a reasonable initial guess
#
# $$
# s_{0} \ = \ \frac{1}{2} \pm i\, t_{0}, \qquad \text{where} \qquad t_{0} > 0.
# $$
#
#
# That is
#
# $$
# s_{n+1} \ = \ s_{n} - \frac{\zeta(s_{n})}{\zeta'(s_{n})}.
# $$
#
# The roots are distributed more-or-less randomly ascending along the $s=1/2$ axis. Exactly how random is the subject of much speculation. The 1st four roots have
#
# $$
# t \quad \approx \quad 14.13472514173469, \quad 21.02203963877155, \quad 25.01085758014568, \quad 30.42487612585951,
# $$
#
# where each number shows 16 correct digits.
#
#
# After that, the roots tend to be spaced a few units apart as far as you care to look. There are 29 roots with $t < 100$. The 29th root has
#
# $$
# t \ \approx \ 98.83119421819369.
# $$
#
# <br>

# %% [markdown]
# # **TASK 2**
#
# Write a function called `zeta_roots(n)` that finds the first $n$ roots of the form:
#
# $$
# \zeta(1/2 + i \, t) = 0 \quad \text{where} \quad t > 0.
# $$
#
# The results should be an ascending-order sorted array of *real* numbers representing the $t$ values for the roots. ***Ideally,***
#
# * The roots should solve the equation $\zeta(1/2 + i \, t) \approx 0$ to roughly machine precision.
#
#
# * The output array should contain *all* of the first $n$ roots, and no duplicates.
#
#
# * If your `zeta(s)` and `zeta_prime(s)` are inaccurate, then your results will still satisfy the equation, but they may not be very close to the "true" roots. You can check against the number provided. But also check if your numbers change if you use more series terms in you original functions.

# %%
### TEST FUNCTION: test_zeta_roots
# DO NOT REMOVE ANYTHING IN THIS CELL

def zeta_roots(n):
    """ Finds the first n non-trivial roots of the Riemann zeta function.
    
    Parameters
    ----------
    n : integer
        non-negative

    Returns
    -------
    ndarray
        Sorted array of the imaginary part of non-trivial roots.
        
    """
    
    ### YOU CODE BELOW THIS LINE ###
    
    
    return

# %%
### SKIP
# This code will not be marked.

# %% [markdown]
# <br>
#
# # **END ASSIGNMENT**
